# %% [markdown]
# # Face Emotion Detection - EfficientNetB0 + MediaPipe
#
# This notebook uses the shared face-emotion training pipeline: 8 emotion classes, YOLO-format dataset support, Google Drive backup, metadata saving, artifact download, and MediaPipe Face Detection. The classification model is EfficientNetB0 transfer learning.

# %% [markdown]
# ## 1. Install Libraries

# %%
# !pip install -q kagglehub tensorflow opencv-python scikit-learn matplotlib pandas pillow mediapipe
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 7.0 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Imports and Project Paths

# %%
import json
import os
import random
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import mediapipe as mp
import numpy as np
import pandas as pd
import tensorflow as tf
from PIL import Image
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    log_loss,
    matthews_corrcoef,
    precision_recall_fscore_support,
    roc_auc_score,
    top_k_accuracy_score,
)
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow import keras
from tensorflow.keras import layers

try:
    import kagglehub
except ImportError:
    kagglehub = None

NOTEBOOK_DIR = Path.cwd().resolve()
PROJECT_ROOT = NOTEBOOK_DIR if (NOTEBOOK_DIR / 'data').exists() else NOTEBOOK_DIR.parent
DATA_DIR = PROJECT_ROOT / 'data'
RAW_DIR = DATA_DIR / 'raw'
PROCESSED_DIR = DATA_DIR / 'processed'
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'
MODEL_DIR = ARTIFACTS_DIR / 'models'
OUTPUT_DIR = ARTIFACTS_DIR / 'outputs'
UPLOAD_DIR = OUTPUT_DIR / 'uploaded_images'

for path in [RAW_DIR, PROCESSED_DIR, MODEL_DIR, OUTPUT_DIR, UPLOAD_DIR]:
    path.mkdir(parents=True, exist_ok=True)

print('TensorFlow:', tf.__version__)
print('MediaPipe:', mp.__version__)
print('GPU devices:', tf.config.list_physical_devices('GPU'))
print('Project root:', PROJECT_ROOT)
print('Raw data dir:', RAW_DIR)
print('Model dir:', MODEL_DIR)
# Out:
# TensorFlow: 2.20.0
# MediaPipe: 0.10.35
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Project root: /
# Raw data dir: /data/raw
# Model dir: /artifacts/models

# %%
# Demo helper functions for visualization
def show_image_grid(dataframe, samples_per_class=4, title='Samples by class'):
    if dataframe.empty:
        print('No images to display.')
        return

    rows = []
    for label in CLASS_NAMES:
        subset = dataframe[dataframe['label'] == label]
        if subset.empty:
            continue
        rows.append(subset.sample(min(samples_per_class, len(subset)), random_state=SEED))

    sample_df = pd.concat(rows).reset_index(drop=True)
    ncols = samples_per_class
    nrows = len(sample_df['label'].unique())
    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 2.4, nrows * 2.4))
    axes = np.asarray(axes).reshape(nrows, ncols)

    for ax in axes.ravel():
        ax.axis('off')

    for row_idx, label in enumerate(sample_df['label'].unique()):
        label_df = sample_df[sample_df['label'] == label].reset_index(drop=True)
        for col_idx, item in label_df.iterrows():
            image = Image.open(item['path']).convert('RGB')
            axes[row_idx, col_idx].imshow(image)
            axes[row_idx, col_idx].set_title(label, fontsize=10)
            axes[row_idx, col_idx].axis('off')

    fig.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 3. Configuration

# %%
SEED = 42
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS_HEAD = 15
EPOCHS_FINE_TUNE = 20
VALID_SIZE = 0.15
TEST_SIZE = 0.15
LEARNING_RATE_HEAD = 1e-3
LEARNING_RATE_FINE = 1e-5
USE_MIXED_PRECISION = True
COPY_DATASETS_TO_RAW = False

KAGGLE_DATASETS = ['mstjebashazida/affectnet','fatihkgg/affectnet-yolo-format']
LOCAL_DATASET_ROOTS = []

CLASS_NAMES = ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
CLASS_TO_ID = {name: idx for idx, name in enumerate(CLASS_NAMES)}
IMAGE_EXTS = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

AFFECTNET_ID_TO_LABEL = {
    0: 'anger',
    1: 'contempt',
    2: 'disgust',
    3: 'fear',
    4: 'happy',
    5: 'neutral',
    6: 'sad',
    7: 'surprise',
}

LABEL_ALIASES = {
    'anger': 'anger', 'angry': 'anger', 'angriness': 'anger',
    'angry_face': 'anger', 'angryface': 'anger', 'mad': 'anger',
    'contempt': 'contempt', 'contemptuous': 'contempt',
    'disgust': 'disgust', 'disgusted': 'disgust', 'disgusting': 'disgust',
    'fear': 'fear', 'fearful': 'fear', 'scared': 'fear', 'afraid': 'fear',
    'happy': 'happy', 'happiness': 'happy', 'joy': 'happy', 'joyful': 'happy',
    'smile': 'happy', 'smiling': 'happy',
    'neutral': 'neutral', 'normal': 'neutral', 'calm': 'neutral',
    'sad': 'sad', 'sadness': 'sad', 'unhappy': 'sad',
    'surprise': 'surprise', 'surprised': 'surprise', 'surprize': 'surprise',
}

AFFECTNET_LABEL_COLUMNS = [
    'expression', 'exp', 'emotion', 'label', 'class', 'category', 'emotion_label', 'expression_label'
]
AFFECTNET_PATH_COLUMNS = [
    'subDirectory_filePath', 'subdirectory_filepath', 'filepath', 'file_path', 'path', 'image', 'image_path', 'filename', 'file'
]

BEST_MODEL_PATH = MODEL_DIR / 'best_efficientnetb0_emotion_model.keras'
FINAL_MODEL_PATH = MODEL_DIR / 'face_emotion_efficientnetb0_mediapipe.keras'
METADATA_PATH = MODEL_DIR / 'metadata_efficientnetb0_mediapipe.json'
DRIVE_MODEL_DIR = '/content/drive/MyDrive/Emotion_Detect_Models/EfficientNetB0'

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

if USE_MIXED_PRECISION and tf.config.list_physical_devices('GPU'):
    tf.keras.mixed_precision.set_global_policy('mixed_float16')
    print('Mixed precision enabled.')
else:
    print('Mixed precision disabled.')
# Out:
# Mixed precision enabled.

# %% [markdown]
# ## 3.1 Mount Google Drive

# %%
from pathlib import Path

try:
    from google.colab import drive  # type: ignore
    drive.mount('/content/drive')

    drive_dir = Path(DRIVE_MODEL_DIR)
    drive_dir.mkdir(parents=True, exist_ok=True)

    print('Drive ready:', drive_dir)
    print('Exists:', drive_dir.exists())
except ImportError:
    print('Not running on Colab. Skipping Google Drive mount.')
# Out:
# Mounted at /content/drive
# Drive ready: /content/drive/MyDrive/Emotion_Detect_Models/EfficientNetB0
# Exists: True

# %% [markdown]
# ## 4. Locate or Download Dataset

# %%
def is_colab_runtime():
    try:
        import google.colab  # type: ignore
        return True
    except ImportError:
        return False


def is_kaggle_runtime():
    return Path('/kaggle/input').exists()


def find_kaggle_input_roots():
    input_dir = Path('/kaggle/input')
    if not input_dir.exists():
        return []
    return [p.resolve() for p in input_dir.iterdir() if p.is_dir()]


def find_local_raw_roots(raw_dir):
    if not raw_dir.exists():
        return []
    return [p.resolve() for p in raw_dir.iterdir() if p.is_dir()]


def prepare_kaggle_credentials():
    kaggle_dir = Path.home() / '.kaggle'
    kaggle_json = kaggle_dir / 'kaggle.json'
    if kaggle_json.exists() or os.environ.get('KAGGLE_USERNAME'):
        return

    if is_kaggle_runtime():
        print('Kaggle runtime detected. Prefer adding the dataset as an Input.')
        return

    if is_colab_runtime():
        print('Upload kaggle.json from your Kaggle account settings.')
        from google.colab import files  # type: ignore
        uploaded = files.upload()
        if 'kaggle.json' not in uploaded:
            raise FileNotFoundError('kaggle.json was not uploaded.')
        kaggle_dir.mkdir(parents=True, exist_ok=True)
        kaggle_json.write_bytes(uploaded['kaggle.json'])
        try:
            os.chmod(kaggle_json, 0o600)
        except OSError:
            pass
        return

    raise FileNotFoundError(
        'No Kaggle credentials found. Put kaggle.json in ~/.kaggle or set KAGGLE_USERNAME/KAGGLE_KEY.'
    )


def download_kaggle_datasets(dataset_slugs, raw_dir, copy_to_raw=False):
    if LOCAL_DATASET_ROOTS:
        roots = [Path(p).expanduser().resolve() for p in LOCAL_DATASET_ROOTS]
        missing = [str(p) for p in roots if not p.exists()]
        if missing:
            raise FileNotFoundError('LOCAL_DATASET_ROOTS not found: ' + ', '.join(missing))
        print('Using LOCAL_DATASET_ROOTS:', roots)
        return roots

    local_roots = find_local_raw_roots(raw_dir)
    if local_roots:
        print('Using dataset folders already present in data/raw:', local_roots)
        return local_roots

    kaggle_input_roots = find_kaggle_input_roots()
    if kaggle_input_roots:
        print('Using Kaggle Input roots:', kaggle_input_roots)
        return kaggle_input_roots

    if kagglehub is None:
        raise ImportError('kagglehub is not installed. Run the install cell first.')

    prepare_kaggle_credentials()

    downloaded_paths = []
    for slug in dataset_slugs:
        print(f'Downloading or locating Kaggle dataset: {slug}')
        dataset_path = Path(kagglehub.dataset_download(slug)).resolve()
        if copy_to_raw:
            target_path = raw_dir / slug.replace('/', '__')
            if target_path.exists():
                print('Target already exists, reusing:', target_path)
            else:
                import shutil
                shutil.copytree(dataset_path, target_path)
            dataset_path = target_path.resolve()
        downloaded_paths.append(dataset_path)
        print('Dataset root:', dataset_path)

    return downloaded_paths


dataset_roots = download_kaggle_datasets(
    KAGGLE_DATASETS,
    RAW_DIR,
    copy_to_raw=COPY_DATASETS_TO_RAW,
)
dataset_roots
# Out:
# Kaggle runtime detected. Prefer adding the dataset as an Input.
# Downloading or locating Kaggle dataset: mstjebashazida/affectnet
# Downloading to /root/.cache/kagglehub/datasets/mstjebashazida/affectnet/1.archive...
# 100%|██████████| 324M/324M [00:01<00:00, 174MB/s]
# Extracting files...
# Dataset root: /root/.cache/kagglehub/datasets/mstjebashazida/affectnet/versions/1
# Downloading or locating Kaggle dataset: fatihkgg/affectnet-yolo-format
# Downloading to /root/.cache/kagglehub/datasets/fatihkgg/affectnet-yolo-format/2.archive...
# 100%|██████████| 258M/258M [00:02<00:00, 106MB/s]
# Extracting files...
# Dataset root: /root/.cache/kagglehub/datasets/fatihkgg/affectnet-yolo-format/versions/2
# [PosixPath('/root/.cache/kagglehub/datasets/mstjebashazida/affectnet/versions/1'),
#  PosixPath('/root/.cache/kagglehub/datasets/fatihkgg/affectnet-yolo-format/versions/2')]

# %% [markdown]
# ## 5. Normalize Labels and Build the Index

# %%
def normalize_label(value, numeric_mapping='affectnet'):
    if pd.isna(value):
        return None

    text = str(value).strip().lower().replace(' ', '_')
    if text in {'', 'nan', 'none', 'uncertain', 'non_face', 'non-face'}:
        return None

    try:
        numeric = int(float(text))
        if numeric_mapping == 'affectnet':
            return AFFECTNET_ID_TO_LABEL.get(numeric)
    except ValueError:
        pass

    return LABEL_ALIASES.get(text)


def infer_label_from_path(path):
    parts = [p.lower().replace(' ', '_') for p in Path(path).parts]
    for part in reversed(parts):
        label = normalize_label(part, numeric_mapping='affectnet')
        if label is not None:
            return label
    return None


def first_matching_column(columns, candidates):
    normalized = {str(col).strip().lower(): col for col in columns}
    for candidate in candidates:
        if candidate.lower() in normalized:
            return normalized[candidate.lower()]
    return None


def find_existing_image(root, value):
    candidate = Path(str(value).strip())
    candidates = []
    if candidate.is_absolute():
        candidates.append(candidate)
    else:
        clean_value = str(value).strip().lstrip('/\\')
        candidates.extend([
            Path(root) / candidate,
            Path(root) / clean_value,
            Path(root) / 'Manually_Annotated' / 'Manually_Annotated_Images' / clean_value,
            Path(root) / 'Automatically_Annotated' / 'Automatically_Annotated_Images' / clean_value,
        ])

    for item in candidates:
        if item.exists() and item.suffix.lower() in IMAGE_EXTS:
            return item.resolve()
    return None


def collect_affectnet_csv_records(root):
    records = []
    for csv_path in Path(root).rglob('*.csv'):
        try:
            sample = pd.read_csv(csv_path, nrows=5)
        except Exception:
            continue

        path_col = first_matching_column(sample.columns, AFFECTNET_PATH_COLUMNS)
        label_col = first_matching_column(sample.columns, AFFECTNET_LABEL_COLUMNS)
        if path_col is None or label_col is None:
            continue

        print('Reading AffectNet annotations:', csv_path)
        for chunk in pd.read_csv(csv_path, usecols=[path_col, label_col], chunksize=50000):
            chunk = chunk.dropna(subset=[path_col, label_col])
            for row in chunk.itertuples(index=False):
                image_value, label_value = row
                label = normalize_label(label_value, numeric_mapping='affectnet')
                if label is None:
                    continue
                image_path = find_existing_image(root, image_value)
                if image_path is None:
                    continue
                records.append({
                    'path': str(image_path),
                    'label': label,
                    'source': Path(root).name,
                    'annotation_file': csv_path.name,
                })
    return records


def collect_folder_label_records(root):
    records = []
    for file_path in Path(root).rglob('*'):
        if file_path.suffix.lower() not in IMAGE_EXTS:
            continue
        label = infer_label_from_path(file_path.relative_to(root))
        if label is not None:
            records.append({
                'path': str(file_path.resolve()),
                'label': label,
                'source': Path(root).name,
                'annotation_file': None,
            })
    return records


def parse_yolo_names(root):
    """Read YOLO class names from data.yaml. Falls back to CLASS_NAMES order."""
    import ast
    import re

    yaml_files = list(Path(root).rglob('data.yaml')) + list(Path(root).rglob('*.yaml'))
    for yaml_path in yaml_files:
        text = yaml_path.read_text(encoding='utf-8', errors='ignore')
        lines = text.splitlines()

        inline = re.search(r'^\s*names\s*:\s*(\[.*\]|\{.*\})\s*$', text, flags=re.MULTILINE)
        if inline:
            try:
                value = ast.literal_eval(inline.group(1))
                if isinstance(value, dict):
                    names = [value[i] for i in sorted(value)]
                else:
                    names = list(value)
                return [normalize_label(name) or str(name).strip().lower() for name in names]
            except Exception:
                pass

        for idx, line in enumerate(lines):
            if line.strip().startswith('names:'):
                names = []
                for child in lines[idx + 1:]:
                    if not child.startswith((' ', '\t', '-')):
                        break
                    cleaned = child.strip().strip(',')
                    if not cleaned:
                        continue
                    if ':' in cleaned:
                        cleaned = cleaned.split(':', 1)[1].strip()
                    if cleaned.startswith('-'):
                        cleaned = cleaned[1:].strip()
                    cleaned = cleaned.strip('"\'')
                    label = normalize_label(cleaned) or cleaned.lower().replace(' ', '_')
                    if label:
                        names.append(label)
                if names:
                    return names

    return CLASS_NAMES


def yolo_label_path_for_image(image_path):
    image_path = Path(image_path)
    parts = list(image_path.parts)
    label_candidates = []

    if 'images' in parts:
        idx = parts.index('images')
        label_parts = parts.copy()
        label_parts[idx] = 'labels'
        label_candidates.append(Path(*label_parts).with_suffix('.txt'))

    label_candidates.append(image_path.with_suffix('.txt'))
    label_candidates.append(image_path.parent.parent / 'labels' / image_path.parent.name / f'{image_path.stem}.txt')
    label_candidates.append(image_path.parent.parent / 'labels' / f'{image_path.stem}.txt')

    for candidate in label_candidates:
        if candidate.exists():
            return candidate
    return None


def crop_yolo_box(image, x_center, y_center, width, height, margin=0.12):
    img_w, img_h = image.size
    x1 = (x_center - width / 2) * img_w
    y1 = (y_center - height / 2) * img_h
    x2 = (x_center + width / 2) * img_w
    y2 = (y_center + height / 2) * img_h

    pad_x = (x2 - x1) * margin
    pad_y = (y2 - y1) * margin
    x1 = max(0, int(round(x1 - pad_x)))
    y1 = max(0, int(round(y1 - pad_y)))
    x2 = min(img_w, int(round(x2 + pad_x)))
    y2 = min(img_h, int(round(y2 + pad_y)))

    if x2 <= x1 or y2 <= y1:
        return None
    return image.crop((x1, y1, x2, y2))


def collect_yolo_records(root):
    root = Path(root)
    yolo_names = parse_yolo_names(root)
    label_files = list(root.rglob('labels/**/*.txt')) + list(root.rglob('labels/*.txt'))
    if not label_files:
        label_files = [p for p in root.rglob('*.txt') if p.name.lower() not in {'classes.txt', 'readme.txt'}]
    if not label_files:
        return []

    print('YOLO class names:', yolo_names)
    crop_root = PROCESSED_DIR / 'yolo_crops' / root.name
    records = []
    image_lookup = {p.with_suffix('').as_posix().lower(): p for p in root.rglob('*') if p.suffix.lower() in IMAGE_EXTS}

    for label_path in label_files:
        possible_keys = []
        if 'labels' in label_path.parts:
            parts = list(label_path.parts)
            idx = parts.index('labels')
            image_parts = parts.copy()
            image_parts[idx] = 'images'
            possible_keys.append(Path(*image_parts).with_suffix('').as_posix().lower())
        possible_keys.append(label_path.with_suffix('').as_posix().lower())

        image_path = None
        for key in possible_keys:
            image_path = image_lookup.get(key)
            if image_path is not None:
                break

        if image_path is None:
            stem_matches = [p for p in image_lookup.values() if p.stem == label_path.stem]
            if len(stem_matches) == 1:
                image_path = stem_matches[0]

        if image_path is None:
            continue

        try:
            image = Image.open(image_path).convert('RGB')
        except Exception:
            continue

        for box_idx, line in enumerate(label_path.read_text(encoding='utf-8', errors='ignore').splitlines()):
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            try:
                class_id = int(float(parts[0]))
                x_center, y_center, width, height = map(float, parts[1:5])
            except ValueError:
                continue
            if class_id < 0 or class_id >= len(yolo_names):
                continue

            label = normalize_label(yolo_names[class_id]) or yolo_names[class_id]
            if label not in CLASS_NAMES:
                continue

            crop = crop_yolo_box(image, x_center, y_center, width, height)
            if crop is None:
                continue

            split_name = 'unknown'
            lower_parts = [p.lower() for p in image_path.parts]
            for candidate in ['train', 'valid', 'val', 'test']:
                if candidate in lower_parts:
                    split_name = 'valid' if candidate == 'val' else candidate
                    break

            target_dir = crop_root / split_name / label
            target_dir.mkdir(parents=True, exist_ok=True)
            target_path = target_dir / f'{image_path.stem}_{box_idx}.jpg'
            if not target_path.exists():
                crop.resize(IMG_SIZE).save(target_path, quality=95)

            records.append({
                'path': str(target_path.resolve()),
                'label': label,
                'source': root.name,
                'annotation_file': str(label_path.relative_to(root)),
            })

    if records:
        print(f'YOLO records created from {root}: {len(records)}')
        print('YOLO crops saved to:', crop_root)
    return records


def collect_image_files(dataset_roots):
    records = []
    for root in dataset_roots:
        root = Path(root)
        csv_records = collect_affectnet_csv_records(root)
        if csv_records:
            records.extend(csv_records)
            continue

        yolo_records = collect_yolo_records(root)
        if yolo_records:
            records.extend(yolo_records)
            continue

        records.extend(collect_folder_label_records(root))

    df_images = pd.DataFrame(records)
    if df_images.empty:
        return pd.DataFrame(columns=['path', 'label', 'source', 'annotation_file'])

    df_images = df_images.drop_duplicates('path').reset_index(drop=True)
    df_images = df_images[df_images['label'].isin(CLASS_NAMES)].copy()
    df_images['label_id'] = df_images['label'].map(CLASS_TO_ID)
    return df_images


df_images = collect_image_files(dataset_roots)
print('Images found:', len(df_images))
display(df_images['label'].value_counts().reindex(CLASS_NAMES).fillna(0).astype(int))
df_images.head()
# Out:
# YOLO class names: ['[', 'anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise', ']']
# YOLO records created from /root/.cache/kagglehub/datasets/fatihkgg/affectnet-yolo-format/versions/2: 43656
# YOLO crops saved to: /data/processed/yolo_crops/2
# Images found: 52454
# label
# anger       6164
# contempt    6112
# disgust     5438
# fear        6520
# happy       7424
# neutral     7921
# sad         8836
# surprise    4039
# Name: count, dtype: int64
#                                                 path    label source  \
# 0  /root/.cache/kagglehub/datasets/mstjebashazida...  neutral      1
# 1  /root/.cache/kagglehub/datasets/mstjebashazida...  neutral      1
# 2  /root/.cache/kagglehub/datasets/mstjebashazida...  neutral      1
# 3  /root/.cache/kagglehub/datasets/mstjebashazida...  neutral      1
# 4  /root/.cache/kagglehub/datasets/mstjebashazida...  neutral      1
#
#   annotation_file  label_id
# 0            None         5
# 1            None         5
# 2            None         5
# 3            None         5
# 4            None         5

# %% [markdown]
# ## 5.1 Data Preview

# %%
print('Total images:', len(df_images))
if not df_images.empty:
    overview = df_images['label'].value_counts().reindex(CLASS_NAMES).fillna(0).astype(int).reset_index()
    overview.columns = ['emotion', 'count']
    overview['percent'] = overview['count'] / overview['count'].sum() * 100
    display(overview)

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.bar(overview['emotion'], overview['count'], color='#4C78A8')
    ax.set_title('Image Count by Emotion')
    ax.set_xlabel('Emotion')
    ax.set_ylabel('Image count')
    ax.grid(axis='y', alpha=0.25)
    plt.xticks(rotation=30, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Total images: 52454
#     emotion  count    percent
# 0     anger   6164  11.751249
# 1  contempt   6112  11.652114
# 2   disgust   5438  10.367179
# 3      fear   6520  12.429939
# 4     happy   7424  14.153353
# 5   neutral   7921  15.100850
# 6       sad   8836  16.845236
# 7  surprise   4039   7.700080

# %%
show_image_grid(df_images, samples_per_class=4, title='Dataset Samples by Emotion')

# %% [markdown]
# ## 6. Train / Validation / Test Split

# %%
if df_images.empty:
    raise ValueError('No valid AffectNet data found.')

min_class_count = int(df_images['label'].value_counts().min())
if min_class_count < 2:
    raise ValueError('Each class needs at least 2 samples for stratified splitting.')

train_df, temp_df = train_test_split(
    df_images,
    test_size=VALID_SIZE + TEST_SIZE,
    stratify=df_images['label'],
    random_state=SEED,
)

relative_test = TEST_SIZE / (VALID_SIZE + TEST_SIZE)
valid_df, test_df = train_test_split(
    temp_df,
    test_size=relative_test,
    stratify=temp_df['label'],
    random_state=SEED,
)

split_summary = pd.DataFrame({
    'train': train_df['label'].value_counts(),
    'valid': valid_df['label'].value_counts(),
    'test': test_df['label'].value_counts(),
}).reindex(CLASS_NAMES).fillna(0).astype(int)

print(len(train_df), len(valid_df), len(test_df))
display(split_summary)

fig, ax = plt.subplots(figsize=(10, 5))
split_summary.plot(kind='bar', ax=ax, color=['#4C78A8', '#F58518', '#54A24B'])
ax.set_title('Train / Validation / Test Split by Emotion')
ax.set_xlabel('Emotion')
ax.set_ylabel('Image count')
ax.legend(title='Split')
ax.grid(axis='y', alpha=0.25)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

train_df.to_csv(PROCESSED_DIR / 'train_split_v2.csv', index=False)
valid_df.to_csv(PROCESSED_DIR / 'valid_split_v2.csv', index=False)
test_df.to_csv(PROCESSED_DIR / 'test_split_v2.csv', index=False)
print('Saved split CSV files to:', PROCESSED_DIR)
# Out:
# 36717 7868 7869
#           train  valid  test
# label
# anger      4315    925   924
# contempt   4278    917   917
# disgust    3806    816   816
# fear       4564    978   978
# happy      5197   1113  1114
# neutral    5545   1188  1188
# sad        6185   1325  1326
# surprise   2827    606   606
# Saved split CSV files to: /data/processed

# %% [markdown]
# ## 7. TensorFlow Datasets

# %%
AUTOTUNE = tf.data.AUTOTUNE


def load_image(path, label):
    image = tf.io.read_file(path)
    image = tf.io.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.cast(image, tf.float32)
    return image, label


def make_dataset(dataframe, training=False):
    paths = dataframe['path'].astype(str).values
    labels = dataframe['label_id'].astype(np.int32).values
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if training:
        ds = ds.shuffle(min(len(dataframe), 10000), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(load_image, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(AUTOTUNE)
    return ds


train_ds = make_dataset(train_df, training=True)
valid_ds = make_dataset(valid_df)
test_ds = make_dataset(test_df)

present_train_classes = np.sort(train_df['label_id'].unique()).astype(int)
missing_train_classes = sorted(set(range(len(CLASS_NAMES))) - set(present_train_classes.tolist()))
if missing_train_classes:
    missing_names = [CLASS_NAMES[i] for i in missing_train_classes]
    print('Warning: these classes are missing from train_df and will use default weight 1.0:', missing_names)

class_weights_arr = compute_class_weight(
    class_weight='balanced',
    classes=present_train_classes,
    y=train_df['label_id'].values,
)
class_weights = {i: 1.0 for i in range(len(CLASS_NAMES))}
class_weights.update({int(cls): float(weight) for cls, weight in zip(present_train_classes, class_weights_arr)})
print('Class weights:', class_weights)

class_weight_df = pd.DataFrame({
    'emotion': CLASS_NAMES,
    'class_weight': [class_weights[i] for i in range(len(CLASS_NAMES))],
    'train_count': [int((train_df['label_id'] == i).sum()) for i in range(len(CLASS_NAMES))],
})
display(class_weight_df)

fig, ax = plt.subplots(figsize=(9, 4))
ax.bar(class_weight_df['emotion'], class_weight_df['class_weight'], color='#72B7B2')
ax.axhline(1.0, color='#333333', linewidth=1, linestyle='--', label='default weight')
ax.set_title('Class Weights Computed from Training Set')
ax.set_xlabel('Emotion')
ax.set_ylabel('Weight')
ax.legend()
ax.grid(axis='y', alpha=0.25)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Class weights: {0: 1.0636442641946697, 1: 1.0728436185133239, 2: 1.205892012611666, 3: 1.005614592462752, 4: 0.883129690205888, 5: 0.8277051397655546, 6: 0.7420573969280517, 7: 1.6234966395472232}
#     emotion  class_weight  train_count
# 0     anger      1.063644         4315
# 1  contempt      1.072844         4278
# 2   disgust      1.205892         3806
# 3      fear      1.005615         4564
# 4     happy      0.883130         5197
# 5   neutral      0.827705         5545
# 6       sad      0.742057         6185
# 7  surprise      1.623497         2827

# %% [markdown]
# ## 8. Build and Train EfficientNetB0

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.12),
    layers.RandomContrast(0.15),
], name='augmentation')

preview_row = train_df.sample(1, random_state=SEED).iloc[0]
preview_image = keras.utils.load_img(preview_row['path'], target_size=IMG_SIZE)
preview_array = keras.utils.img_to_array(preview_image)

augmentation_examples = [
    ('Original', preview_array),
    ('Horizontal flip', tf.image.flip_left_right(preview_array).numpy()),
    ('Small rotation', layers.RandomRotation(0.10, fill_mode='nearest', seed=SEED)(preview_array[None, ...], training=True)[0].numpy()),
    ('Zoom', layers.RandomZoom(0.12, fill_mode='nearest', seed=SEED)(preview_array[None, ...], training=True)[0].numpy()),
    ('Contrast', tf.image.adjust_contrast(preview_array, 1.4).numpy()),
]

fig, axes = plt.subplots(1, len(augmentation_examples), figsize=(15, 3))
for ax, (title, image) in zip(axes, augmentation_examples):
    ax.imshow(np.clip(image, 0, 255).astype('uint8'))
    ax.set_title(title, fontsize=10)
    ax.axis('off')
fig.suptitle('Training-time Data Augmentation Preview', fontsize=14)
fig.tight_layout()
plt.show()

base_model = keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=IMG_SIZE + (3,),
)
base_model.trainable = False

inputs = keras.Input(shape=IMG_SIZE + (3,), name='image')
x = data_augmentation(inputs)
# EfficientNet preprocessing is included in the Keras EfficientNet model.
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = layers.BatchNormalization(name='head_bn')(x)
x = layers.Dropout(0.35, name='head_dropout')(x)
outputs = layers.Dense(len(CLASS_NAMES), activation='softmax', dtype='float32', name='emotion')(x)

model = keras.Model(inputs, outputs, name='EfficientNetB0_Emotion_Classifier')
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE_HEAD),
    loss='sparse_categorical_crossentropy',
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
        keras.metrics.SparseTopKCategoricalAccuracy(k=2, name='top2_accuracy'),
        keras.metrics.SparseTopKCategoricalAccuracy(k=3, name='top3_accuracy'),
    ],
)
model.summary()

callbacks = [
    keras.callbacks.ModelCheckpoint(
        BEST_MODEL_PATH,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True,
        verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        mode='max',
        patience=7,
        restore_best_weights=True,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1,
    ),
]

architecture_steps = [
    'Input\n224 x 224 x 3',
    'Data\naugmentation',
    'EfficientNetB0\npreprocessing',
    'EfficientNetB0\nbackbone',
    'Global Avg\nPooling',
    'BatchNorm\n+ Dropout',
    'Dense Softmax\n8 emotions',
]
fig, ax = plt.subplots(figsize=(15, 3))
ax.axis('off')
for i, step in enumerate(architecture_steps):
    x = i / (len(architecture_steps) - 1)
    ax.text(x, 0.5, step, ha='center', va='center', fontsize=10,
            bbox=dict(boxstyle='round,pad=0.45', facecolor='#F2F4F7', edgecolor='#344054'))
    if i < len(architecture_steps) - 1:
        next_x = (i + 1) / (len(architecture_steps) - 1)
        ax.annotate('', xy=(next_x - 0.055, 0.5), xytext=(x + 0.055, 0.5),
                    arrowprops=dict(arrowstyle='->', linewidth=1.5, color='#333333'))
ax.set_title('EfficientNetB0 Transfer Learning Architecture', fontsize=14, pad=18)
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for ax in axes:
    ax.axis('off')
axes[0].text(0.5, 0.72, 'Stage 1', ha='center', va='center', fontsize=14, weight='bold')
axes[0].text(0.5, 0.48, 'Freeze EfficientNetB0 backbone\nTrain only classification head\nLR = 1e-3',
             ha='center', va='center', fontsize=11,
             bbox=dict(boxstyle='round,pad=0.6', facecolor='#EAF2F8', edgecolor='#2F5D7C'))
axes[1].text(0.5, 0.72, 'Stage 2', ha='center', va='center', fontsize=14, weight='bold')
axes[1].text(0.5, 0.48, 'Unfreeze later 40% layers\nFine-tune emotion features\nLR = 1e-5',
             ha='center', va='center', fontsize=11,
             bbox=dict(boxstyle='round,pad=0.6', facecolor='#ECFDF3', edgecolor='#26734D'))
fig.suptitle('Two-Stage Training Strategy', fontsize=14)
plt.tight_layout()
plt.show()

history_head = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=EPOCHS_HEAD,
    callbacks=callbacks,
    class_weight=class_weights,
)

base_model.trainable = True
fine_tune_at = int(len(base_model.layers) * 0.60)
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Keep BatchNormalization layers frozen during fine-tuning for stability.
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE_FINE),
    loss='sparse_categorical_crossentropy',
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
        keras.metrics.SparseTopKCategoricalAccuracy(k=2, name='top2_accuracy'),
        keras.metrics.SparseTopKCategoricalAccuracy(k=3, name='top3_accuracy'),
    ],
)

history_fine = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=EPOCHS_FINE_TUNE,
    callbacks=callbacks,
    class_weight=class_weights,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB0_Emotion_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_avg_pool                 │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ head_bn (BatchNormalization)    │ (None, 1280)           │         5,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ head_dropout (Dropout)          │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ emotion (Dense)                 │ (None, 8)              │        10,248 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,064,939 (15.51 MB)
#  Trainable params: 12,808 (50.03 KB)
#  Non-trainable params: 4,052,131 (15.46 MB)
# Epoch 1/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2094 - loss: 2.3898 - top2_accuracy: 0.3755 - top3_accuracy: 0.5169
# Epoch 1: val_accuracy improved from None to 0.28711, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 1: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 218s 78ms/step - accuracy: 0.2269 - loss: 2.2118 - top2_accuracy: 0.4071 - top3_accuracy: 0.5541 - val_accuracy: 0.2871 - val_loss: 1.8623 - val_top2_accuracy: 0.4968 - val_top3_accuracy: 0.6468 - learning_rate: 0.0010
# Epoch 2/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2468 - loss: 2.0395 - top2_accuracy: 0.4419 - top3_accuracy: 0.5898
# Epoch 2: val_accuracy did not improve from 0.28711
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 129s 56ms/step - accuracy: 0.2494 - loss: 2.0209 - top2_accuracy: 0.4489 - top3_accuracy: 0.5961 - val_accuracy: 0.2820 - val_loss: 1.8824 - val_top2_accuracy: 0.4981 - val_top3_accuracy: 0.6368 - learning_rate: 0.0010
# Epoch 3/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2548 - loss: 1.9884 - top2_accuracy: 0.4502 - top3_accuracy: 0.5972
# Epoch 3: val_accuracy improved from 0.28711 to 0.28749, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 3: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 132s 57ms/step - accuracy: 0.2542 - loss: 1.9794 - top2_accuracy: 0.4518 - top3_accuracy: 0.6023 - val_accuracy: 0.2875 - val_loss: 1.8341 - val_top2_accuracy: 0.5084 - val_top3_accuracy: 0.6593 - learning_rate: 0.0010
# Epoch 4/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2600 - loss: 1.9535 - top2_accuracy: 0.4604 - top3_accuracy: 0.6080
# Epoch 4: val_accuracy did not improve from 0.28749
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 130s 57ms/step - accuracy: 0.2602 - loss: 1.9515 - top2_accuracy: 0.4622 - top3_accuracy: 0.6112 - val_accuracy: 0.2834 - val_loss: 1.8287 - val_top2_accuracy: 0.5100 - val_top3_accuracy: 0.6632 - learning_rate: 0.0010
# Epoch 5/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2652 - loss: 1.9374 - top2_accuracy: 0.4657 - top3_accuracy: 0.6115
# Epoch 5: val_accuracy improved from 0.28749 to 0.30262, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 5: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 132s 57ms/step - accuracy: 0.2606 - loss: 1.9336 - top2_accuracy: 0.4643 - top3_accuracy: 0.6130 - val_accuracy: 0.3026 - val_loss: 1.8067 - val_top2_accuracy: 0.5163 - val_top3_accuracy: 0.6604 - learning_rate: 0.0010
# Epoch 6/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2685 - loss: 1.9008 - top2_accuracy: 0.4765 - top3_accuracy: 0.6218
# Epoch 6: val_accuracy did not improve from 0.30262
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 129s 56ms/step - accuracy: 0.2697 - loss: 1.9033 - top2_accuracy: 0.4747 - top3_accuracy: 0.6218 - val_accuracy: 0.3020 - val_loss: 1.7966 - val_top2_accuracy: 0.5254 - val_top3_accuracy: 0.6670 - learning_rate: 0.0010
# Epoch 7/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2737 - loss: 1.8943 - top2_accuracy: 0.4771 - top3_accuracy: 0.6241
# Epoch 7: val_accuracy improved from 0.30262 to 0.30452, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 7: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 130s 56ms/step - accuracy: 0.2738 - loss: 1.8910 - top2_accuracy: 0.4782 - top3_accuracy: 0.6268 - val_accuracy: 0.3045 - val_loss: 1.7961 - val_top2_accuracy: 0.5285 - val_top3_accuracy: 0.6674 - learning_rate: 0.0010
# Epoch 8/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2727 - loss: 1.8766 - top2_accuracy: 0.4838 - top3_accuracy: 0.6326
# Epoch 8: val_accuracy improved from 0.30452 to 0.30974, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 8: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 141s 56ms/step - accuracy: 0.2747 - loss: 1.8767 - top2_accuracy: 0.4837 - top3_accuracy: 0.6307 - val_accuracy: 0.3097 - val_loss: 1.7877 - val_top2_accuracy: 0.5301 - val_top3_accuracy: 0.6740 - learning_rate: 0.0010
# Epoch 9/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2768 - loss: 1.8660 - top2_accuracy: 0.4879 - top3_accuracy: 0.6353
# Epoch 9: val_accuracy did not improve from 0.30974
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 129s 56ms/step - accuracy: 0.2761 - loss: 1.8697 - top2_accuracy: 0.4849 - top3_accuracy: 0.6337 - val_accuracy: 0.3086 - val_loss: 1.7874 - val_top2_accuracy: 0.5343 - val_top3_accuracy: 0.6760 - learning_rate: 0.0010
# Epoch 10/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2783 - loss: 1.8655 - top2_accuracy: 0.4886 - top3_accuracy: 0.6330
# Epoch 10: val_accuracy did not improve from 0.30974
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 127s 55ms/step - accuracy: 0.2788 - loss: 1.8603 - top2_accuracy: 0.4912 - top3_accuracy: 0.6360 - val_accuracy: 0.3031 - val_loss: 1.7863 - val_top2_accuracy: 0.5337 - val_top3_accuracy: 0.6772 - learning_rate: 0.0010
# Epoch 11/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2807 - loss: 1.8569 - top2_accuracy: 0.4904 - top3_accuracy: 0.6371
# Epoch 11: val_accuracy improved from 0.30974 to 0.31520, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 11: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 128s 56ms/step - accuracy: 0.2825 - loss: 1.8562 - top2_accuracy: 0.4902 - top3_accuracy: 0.6392 - val_accuracy: 0.3152 - val_loss: 1.7739 - val_top2_accuracy: 0.5413 - val_top3_accuracy: 0.6829 - learning_rate: 0.0010
# Epoch 12/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2891 - loss: 1.8414 - top2_accuracy: 0.4991 - top3_accuracy: 0.6427
# Epoch 12: val_accuracy did not improve from 0.31520
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 130s 56ms/step - accuracy: 0.2859 - loss: 1.8472 - top2_accuracy: 0.4961 - top3_accuracy: 0.6398 - val_accuracy: 0.3147 - val_loss: 1.7699 - val_top2_accuracy: 0.5438 - val_top3_accuracy: 0.6815 - learning_rate: 0.0010
# Epoch 13/15
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2831 - loss: 1.8529 - top2_accuracy: 0.4917 - top3_accuracy: 0.6409
# Epoch 13: val_accuracy did not improve from 0.31520
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 129s 56ms/step - accuracy: 0.2819 - loss: 1.8500 - top2_accuracy: 0.4923 - top3_accuracy: 0.6410 - val_accuracy: 0.3071 - val_loss: 1.7934 - val_top2_accuracy: 0.5333 - val_top3_accuracy: 0.6755 - learning_rate: 0.0010
# Epoch 14/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2805 - loss: 1.8531 - top2_accuracy: 0.4876 - top3_accuracy: 0.6344
# Epoch 14: val_accuracy did not improve from 0.31520
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 129s 56ms/step - accuracy: 0.2828 - loss: 1.8494 - top2_accuracy: 0.4910 - top3_accuracy: 0.6384 - val_accuracy: 0.3062 - val_loss: 1.7719 - val_top2_accuracy: 0.5413 - val_top3_accuracy: 0.6857 - learning_rate: 0.0010
# Epoch 15/15
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2803 - loss: 1.8463 - top2_accuracy: 0.4929 - top3_accuracy: 0.6439
# Epoch 15: val_accuracy improved from 0.31520 to 0.31558, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 15: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 131s 57ms/step - accuracy: 0.2834 - loss: 1.8446 - top2_accuracy: 0.4942 - top3_accuracy: 0.6430 - val_accuracy: 0.3156 - val_loss: 1.7653 - val_top2_accuracy: 0.5445 - val_top3_accuracy: 0.6845 - learning_rate: 0.0010
# Epoch 1/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3052 - loss: 1.7899 - top2_accuracy: 0.5277 - top3_accuracy: 0.6691
# Epoch 1: val_accuracy improved from 0.31558 to 0.37456, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 1: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 235s 86ms/step - accuracy: 0.3203 - loss: 1.7543 - top2_accuracy: 0.5447 - top3_accuracy: 0.6859 - val_accuracy: 0.3746 - val_loss: 1.6395 - val_top2_accuracy: 0.6104 - val_top3_accuracy: 0.7415 - learning_rate: 1.0000e-05
# Epoch 2/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.3527 - loss: 1.6758 - top2_accuracy: 0.5818 - top3_accuracy: 0.7168
# Epoch 2: val_accuracy improved from 0.37456 to 0.41268, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 2: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.3594 - loss: 1.6551 - top2_accuracy: 0.5902 - top3_accuracy: 0.7263 - val_accuracy: 0.4127 - val_loss: 1.5517 - val_top2_accuracy: 0.6412 - val_top3_accuracy: 0.7698 - learning_rate: 1.0000e-05
# Epoch 3/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.3729 - loss: 1.6042 - top2_accuracy: 0.6146 - top3_accuracy: 0.7443
# Epoch 3: val_accuracy improved from 0.41268 to 0.43531, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 3: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.3802 - loss: 1.5916 - top2_accuracy: 0.6176 - top3_accuracy: 0.7485 - val_accuracy: 0.4353 - val_loss: 1.4814 - val_top2_accuracy: 0.6600 - val_top3_accuracy: 0.7907 - learning_rate: 1.0000e-05
# Epoch 4/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4034 - loss: 1.5375 - top2_accuracy: 0.6384 - top3_accuracy: 0.7662
# Epoch 4: val_accuracy improved from 0.43531 to 0.47509, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 4: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 178s 77ms/step - accuracy: 0.4111 - loss: 1.5221 - top2_accuracy: 0.6451 - top3_accuracy: 0.7731 - val_accuracy: 0.4751 - val_loss: 1.3983 - val_top2_accuracy: 0.6871 - val_top3_accuracy: 0.8135 - learning_rate: 1.0000e-05
# Epoch 5/20
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4308 - loss: 1.4797 - top2_accuracy: 0.6615 - top3_accuracy: 0.7903
# Epoch 5: val_accuracy improved from 0.47509 to 0.50458, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 5: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 180s 78ms/step - accuracy: 0.4382 - loss: 1.4627 - top2_accuracy: 0.6675 - top3_accuracy: 0.7923 - val_accuracy: 0.5046 - val_loss: 1.3229 - val_top2_accuracy: 0.7143 - val_top3_accuracy: 0.8334 - learning_rate: 1.0000e-05
# Epoch 6/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4539 - loss: 1.4187 - top2_accuracy: 0.6803 - top3_accuracy: 0.8034
# Epoch 6: val_accuracy improved from 0.50458 to 0.52644, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 6: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 179s 78ms/step - accuracy: 0.4608 - loss: 1.4045 - top2_accuracy: 0.6880 - top3_accuracy: 0.8104 - val_accuracy: 0.5264 - val_loss: 1.2574 - val_top2_accuracy: 0.7405 - val_top3_accuracy: 0.8503 - learning_rate: 1.0000e-05
# Epoch 7/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4809 - loss: 1.3656 - top2_accuracy: 0.7063 - top3_accuracy: 0.8243
# Epoch 7: val_accuracy improved from 0.52644 to 0.55707, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 7: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.4868 - loss: 1.3527 - top2_accuracy: 0.7092 - top3_accuracy: 0.8253 - val_accuracy: 0.5571 - val_loss: 1.2012 - val_top2_accuracy: 0.7574 - val_top3_accuracy: 0.8640 - learning_rate: 1.0000e-05
# Epoch 8/20
# 2294/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5033 - loss: 1.3140 - top2_accuracy: 0.7212 - top3_accuracy: 0.8366
# Epoch 8: val_accuracy improved from 0.55707 to 0.56215, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 8: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 176s 77ms/step - accuracy: 0.5070 - loss: 1.3065 - top2_accuracy: 0.7240 - top3_accuracy: 0.8385 - val_accuracy: 0.5622 - val_loss: 1.1673 - val_top2_accuracy: 0.7728 - val_top3_accuracy: 0.8711 - learning_rate: 1.0000e-05
# Epoch 9/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5169 - loss: 1.2845 - top2_accuracy: 0.7334 - top3_accuracy: 0.8460
# Epoch 9: val_accuracy improved from 0.56215 to 0.57410, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 9: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 179s 78ms/step - accuracy: 0.5204 - loss: 1.2752 - top2_accuracy: 0.7379 - top3_accuracy: 0.8484 - val_accuracy: 0.5741 - val_loss: 1.1422 - val_top2_accuracy: 0.7805 - val_top3_accuracy: 0.8819 - learning_rate: 1.0000e-05
# Epoch 10/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5327 - loss: 1.2487 - top2_accuracy: 0.7471 - top3_accuracy: 0.8523
# Epoch 10: val_accuracy improved from 0.57410 to 0.58897, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 10: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 203s 78ms/step - accuracy: 0.5348 - loss: 1.2408 - top2_accuracy: 0.7502 - top3_accuracy: 0.8552 - val_accuracy: 0.5890 - val_loss: 1.1051 - val_top2_accuracy: 0.7925 - val_top3_accuracy: 0.8866 - learning_rate: 1.0000e-05
# Epoch 11/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5393 - loss: 1.2299 - top2_accuracy: 0.7528 - top3_accuracy: 0.8583
# Epoch 11: val_accuracy improved from 0.58897 to 0.59596, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 11: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.5464 - loss: 1.2129 - top2_accuracy: 0.7583 - top3_accuracy: 0.8631 - val_accuracy: 0.5960 - val_loss: 1.0841 - val_top2_accuracy: 0.7974 - val_top3_accuracy: 0.8913 - learning_rate: 1.0000e-05
# Epoch 12/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5555 - loss: 1.1898 - top2_accuracy: 0.7639 - top3_accuracy: 0.8685
# Epoch 12: val_accuracy improved from 0.59596 to 0.60168, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 12: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 179s 78ms/step - accuracy: 0.5590 - loss: 1.1830 - top2_accuracy: 0.7669 - top3_accuracy: 0.8703 - val_accuracy: 0.6017 - val_loss: 1.0645 - val_top2_accuracy: 0.8086 - val_top3_accuracy: 0.8983 - learning_rate: 1.0000e-05
# Epoch 13/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5662 - loss: 1.1695 - top2_accuracy: 0.7736 - top3_accuracy: 0.8730
# Epoch 13: val_accuracy improved from 0.60168 to 0.61629, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 13: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 180s 78ms/step - accuracy: 0.5692 - loss: 1.1581 - top2_accuracy: 0.7774 - top3_accuracy: 0.8751 - val_accuracy: 0.6163 - val_loss: 1.0330 - val_top2_accuracy: 0.8162 - val_top3_accuracy: 0.8995 - learning_rate: 1.0000e-05
# Epoch 14/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5779 - loss: 1.1437 - top2_accuracy: 0.7828 - top3_accuracy: 0.8780
# Epoch 14: val_accuracy improved from 0.61629 to 0.61718, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 14: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 181s 79ms/step - accuracy: 0.5808 - loss: 1.1327 - top2_accuracy: 0.7870 - top3_accuracy: 0.8810 - val_accuracy: 0.6172 - val_loss: 1.0343 - val_top2_accuracy: 0.8183 - val_top3_accuracy: 0.9024 - learning_rate: 1.0000e-05
# Epoch 15/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5862 - loss: 1.1140 - top2_accuracy: 0.7942 - top3_accuracy: 0.8880
# Epoch 15: val_accuracy improved from 0.61718 to 0.62989, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 15: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 184s 80ms/step - accuracy: 0.5899 - loss: 1.1083 - top2_accuracy: 0.7947 - top3_accuracy: 0.8872 - val_accuracy: 0.6299 - val_loss: 1.0046 - val_top2_accuracy: 0.8263 - val_top3_accuracy: 0.9086 - learning_rate: 1.0000e-05
# Epoch 16/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5914 - loss: 1.1043 - top2_accuracy: 0.7944 - top3_accuracy: 0.8903
# Epoch 16: val_accuracy improved from 0.62989 to 0.63167, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 16: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 180s 79ms/step - accuracy: 0.5953 - loss: 1.0972 - top2_accuracy: 0.7957 - top3_accuracy: 0.8899 - val_accuracy: 0.6317 - val_loss: 0.9977 - val_top2_accuracy: 0.8288 - val_top3_accuracy: 0.9090 - learning_rate: 1.0000e-05
# Epoch 17/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6059 - loss: 1.0806 - top2_accuracy: 0.8025 - top3_accuracy: 0.8941
# Epoch 17: val_accuracy improved from 0.63167 to 0.64006, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 17: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 185s 81ms/step - accuracy: 0.6055 - loss: 1.0745 - top2_accuracy: 0.8032 - top3_accuracy: 0.8945 - val_accuracy: 0.6401 - val_loss: 0.9797 - val_top2_accuracy: 0.8336 - val_top3_accuracy: 0.9122 - learning_rate: 1.0000e-05
# Epoch 18/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6138 - loss: 1.0632 - top2_accuracy: 0.8026 - top3_accuracy: 0.8915
# Epoch 18: val_accuracy did not improve from 0.64006
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 181s 79ms/step - accuracy: 0.6140 - loss: 1.0552 - top2_accuracy: 0.8065 - top3_accuracy: 0.8944 - val_accuracy: 0.6268 - val_loss: 1.0103 - val_top2_accuracy: 0.8238 - val_top3_accuracy: 0.9072 - learning_rate: 1.0000e-05
# Epoch 19/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6122 - loss: 1.0414 - top2_accuracy: 0.8132 - top3_accuracy: 0.8997
# Epoch 19: val_accuracy did not improve from 0.64006
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 178s 77ms/step - accuracy: 0.6123 - loss: 1.0437 - top2_accuracy: 0.8132 - top3_accuracy: 0.9005 - val_accuracy: 0.6350 - val_loss: 0.9939 - val_top2_accuracy: 0.8275 - val_top3_accuracy: 0.9098 - learning_rate: 1.0000e-05
# Epoch 20/20
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6219 - loss: 1.0278 - top2_accuracy: 0.8170 - top3_accuracy: 0.9036
# Epoch 20: val_accuracy improved from 0.64006 to 0.65061, saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
#
# Epoch 20: finished saving model to /artifacts/models/best_efficientnetb0_emotion_model.keras
# 2295/2295 ━━━━━━━━━━━━━━━━━━━━ 180s 78ms/step - accuracy: 0.6240 - loss: 1.0251 - top2_accuracy: 0.8147 - top3_accuracy: 0.9030 - val_accuracy: 0.6506 - val_loss: 0.9514 - val_top2_accuracy: 0.8391 - val_top3_accuracy: 0.9165 - learning_rate: 1.0000e-05

# %% [markdown]
# ## 9.1 Download Model and Metadata

# %%
def download_training_artifacts(
    model_path=FINAL_MODEL_PATH,
    metadata_path=METADATA_PATH,
    include_best_model=True,
    best_model_path=BEST_MODEL_PATH,
    zip_name='face_emotion_efficientnetb0_mediapipe_artifacts.zip',
):
    import zipfile
    from pathlib import Path

    artifact_paths = [Path(model_path), Path(metadata_path)]
    if include_best_model:
        artifact_paths.append(Path(best_model_path))

    existing_paths = []
    missing_paths = []
    for artifact_path in artifact_paths:
        if artifact_path.exists():
            existing_paths.append(artifact_path)
        else:
            missing_paths.append(artifact_path)

    if missing_paths:
        print('Missing artifacts:')
        for missing_path in missing_paths:
            print('-', missing_path)

    if not existing_paths:
        raise FileNotFoundError('No artifacts found to download. Train and save the model first.')

    zip_path = Path(zip_name)
    with zipfile.ZipFile(zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as zip_file:
        for artifact_path in existing_paths:
            zip_file.write(artifact_path, arcname=artifact_path.name)

    print('Created download zip:', zip_path.resolve())
    print('Included files:')
    for artifact_path in existing_paths:
        print('-', artifact_path)

    try:
        from google.colab import files  # type: ignore
        files.download(str(zip_path))
    except ImportError:
        print('Not running on Colab. Download the zip manually from:', zip_path.resolve())

    return zip_path


def save_artifacts_to_drive(
    drive_dir=DRIVE_MODEL_DIR,
    model_path=FINAL_MODEL_PATH,
    metadata_path=METADATA_PATH,
    best_model_path=BEST_MODEL_PATH,
):
    import shutil
    from pathlib import Path

    try:
        from google.colab import drive  # type: ignore
        drive.mount('/content/drive')
    except ImportError:
        print('Not running on Colab. Skipping Google Drive copy.')
        return None

    drive_dir = Path(drive_dir)
    drive_dir.mkdir(parents=True, exist_ok=True)

    copied_paths = []
    for artifact_path in [Path(model_path), Path(metadata_path), Path(best_model_path)]:
        if artifact_path.exists():
            target_path = drive_dir / artifact_path.name
            shutil.copy2(artifact_path, target_path)
            copied_paths.append(target_path)
            print('Saved to Drive:', target_path)
        else:
            print('Missing artifact, not copied:', artifact_path)

    return copied_paths


# Run manually after the Evaluate and Save Artifacts cell if needed.
# download_training_artifacts()
# save_artifacts_to_drive()

# %% [markdown]
# ## 9. Evaluate and Save Artifacts

# %%
def merge_history(*histories):
    merged = {}
    for hist in histories:
        for key, values in hist.history.items():
            merged.setdefault(key, []).extend([float(v) for v in values])
    return merged


REPORT_DIR = OUTPUT_DIR / 'efficientnetb0_reports'
REPORT_DIR.mkdir(parents=True, exist_ok=True)

best_model = keras.models.load_model(BEST_MODEL_PATH)
eval_results = best_model.evaluate(test_ds, verbose=1, return_dict=True)
eval_results = {key: float(value) for key, value in eval_results.items()}
print('Evaluation metrics from model.evaluate:')
display(pd.DataFrame(eval_results.items(), columns=['metric', 'value']))


y_true = []
y_prob = []
for images, labels in test_ds:
    probs = best_model.predict(images, verbose=0)
    y_true.extend(labels.numpy().astype(int).tolist())
    y_prob.extend(probs.astype(float).tolist())

y_true = np.asarray(y_true, dtype=np.int64)
y_prob = np.asarray(y_prob, dtype=np.float64)
y_pred = np.argmax(y_prob, axis=1)
all_label_ids = list(range(len(CLASS_NAMES)))

precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
    y_true, y_pred, labels=all_label_ids, average='macro', zero_division=0
)
precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
    y_true, y_pred, labels=all_label_ids, average='weighted', zero_division=0
)

metrics_summary = {
    **eval_results,
    'accuracy_sklearn': float(accuracy_score(y_true, y_pred)),
    'balanced_accuracy': float(balanced_accuracy_score(y_true, y_pred)),
    'precision_macro': float(precision_macro),
    'recall_macro': float(recall_macro),
    'f1_macro': float(f1_macro),
    'precision_weighted': float(precision_weighted),
    'recall_weighted': float(recall_weighted),
    'f1_weighted': float(f1_weighted),
    'top2_accuracy_sklearn': float(top_k_accuracy_score(y_true, y_prob, k=2, labels=all_label_ids)),
    'top3_accuracy_sklearn': float(top_k_accuracy_score(y_true, y_prob, k=3, labels=all_label_ids)),
    'log_loss': float(log_loss(y_true, y_prob, labels=all_label_ids)),
    'cohen_kappa': float(cohen_kappa_score(y_true, y_pred, labels=all_label_ids)),
    'matthews_corrcoef': float(matthews_corrcoef(y_true, y_pred)),
}

try:
    y_true_onehot = keras.utils.to_categorical(y_true, num_classes=len(CLASS_NAMES))
    metrics_summary['roc_auc_ovr_macro'] = float(roc_auc_score(y_true_onehot, y_prob, average='macro', multi_class='ovr'))
    metrics_summary['roc_auc_ovr_weighted'] = float(roc_auc_score(y_true_onehot, y_prob, average='weighted', multi_class='ovr'))
except ValueError as exc:
    print('ROC AUC skipped:', exc)

metrics_df = pd.DataFrame(metrics_summary.items(), columns=['metric', 'value']).sort_values('metric')
display(metrics_df)
metrics_df.to_csv(REPORT_DIR / 'metrics_summary.csv', index=False)

report_dict = classification_report(
    y_true,
    y_pred,
    labels=all_label_ids,
    target_names=CLASS_NAMES,
    zero_division=0,
    output_dict=True,
)
report_df = pd.DataFrame(report_dict).transpose()
display(report_df)
report_df.to_csv(REPORT_DIR / 'classification_report.csv')

print(classification_report(
    y_true,
    y_pred,
    labels=all_label_ids,
    target_names=CLASS_NAMES,
    zero_division=0,
))

cm = confusion_matrix(y_true, y_pred, labels=all_label_ids)
cm_df = pd.DataFrame(cm, index=CLASS_NAMES, columns=CLASS_NAMES)
display(cm_df)
cm_df.to_csv(REPORT_DIR / 'confusion_matrix_counts.csv')

cm_norm = confusion_matrix(y_true, y_pred, labels=all_label_ids, normalize='true')
cm_norm_df = pd.DataFrame(cm_norm, index=CLASS_NAMES, columns=CLASS_NAMES)
display(cm_norm_df)
cm_norm_df.to_csv(REPORT_DIR / 'confusion_matrix_normalized.csv')

fig, axes = plt.subplots(1, 2, figsize=(16, 7))
ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES).plot(ax=axes[0], xticks_rotation=45, cmap='Blues', colorbar=False)
axes[0].set_title('Confusion Matrix - Counts')
ConfusionMatrixDisplay(cm_norm, display_labels=CLASS_NAMES).plot(ax=axes[1], xticks_rotation=45, cmap='Blues', values_format='.2f', colorbar=False)
axes[1].set_title('Confusion Matrix - Normalized by True Class')
plt.tight_layout()
plt.savefig(REPORT_DIR / 'confusion_matrices.png', dpi=160, bbox_inches='tight')
plt.show()

per_class = report_df.loc[CLASS_NAMES, ['precision', 'recall', 'f1-score', 'support']].copy()
fig, ax = plt.subplots(figsize=(12, 5))
per_class[['precision', 'recall', 'f1-score']].plot(kind='bar', ax=ax)
ax.set_ylim(0, 1)
ax.set_ylabel('Score')
ax.set_title('Per-Class Precision / Recall / F1')
ax.grid(axis='y', alpha=0.25)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(REPORT_DIR / 'per_class_metrics.png', dpi=160, bbox_inches='tight')
plt.show()

hist = merge_history(history_head, history_fine)
history_df = pd.DataFrame(hist)
display(history_df.tail())
history_df.to_csv(REPORT_DIR / 'training_history.csv', index_label='epoch')

plot_pairs = [
    ('accuracy', 'val_accuracy', 'Accuracy'),
    ('top2_accuracy', 'val_top2_accuracy', 'Top-2 Accuracy'),
    ('top3_accuracy', 'val_top3_accuracy', 'Top-3 Accuracy'),
    ('loss', 'val_loss', 'Loss'),
]
fig, axes = plt.subplots(2, 2, figsize=(14, 9))
for ax, (train_key, valid_key, title) in zip(axes.ravel(), plot_pairs):
    if train_key in hist:
        ax.plot(hist[train_key], label='train')
    if valid_key in hist:
        ax.plot(hist[valid_key], label='valid')
    ax.set_title(title)
    ax.set_xlabel('Epoch')
    ax.grid(alpha=0.25)
    ax.legend()
plt.tight_layout()
plt.savefig(REPORT_DIR / 'training_curves.png', dpi=160, bbox_inches='tight')
plt.show()

best_model.save(FINAL_MODEL_PATH)

metadata = {
    'model_name': 'EfficientNetB0',
    'class_names': CLASS_NAMES,
    'img_size': IMG_SIZE,
    'kaggle_datasets': KAGGLE_DATASETS,
    'dataset_roots': [str(p) for p in dataset_roots],
    'train_samples': int(len(train_df)),
    'valid_samples': int(len(valid_df)),
    'test_samples': int(len(test_df)),
    'metrics': metrics_summary,
    'test_accuracy': float(metrics_summary.get('accuracy', metrics_summary['accuracy_sklearn'])),
    'balanced_accuracy': float(metrics_summary['balanced_accuracy']),
    'f1_macro': float(metrics_summary['f1_macro']),
    'f1_weighted': float(metrics_summary['f1_weighted']),
    'class_weights': class_weights,
    'face_detector': 'MediaPipe Face Detection',
    'report_dir': str(REPORT_DIR),
}

with open(METADATA_PATH, 'w', encoding='utf-8') as f:
    json.dump(metadata, f, ensure_ascii=False, indent=2)

with open(REPORT_DIR / 'metrics_summary.json', 'w', encoding='utf-8') as f:
    json.dump(metrics_summary, f, ensure_ascii=False, indent=2)

print('Saved model:', FINAL_MODEL_PATH)
print('Saved metadata:', METADATA_PATH)
print('Saved reports:', REPORT_DIR)

try:
    save_artifacts_to_drive()
except NameError:
    print('save_artifacts_to_drive is not defined. Run the download/drive helper cell before this cell if you want Drive backup.')
# Out:
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.6690 - loss: 0.9072 - top2_accuracy: 0.8550 - top3_accuracy: 0.9269
# Evaluation metrics from model.evaluate:
#           metric     value
# 0       accuracy  0.668954
# 1           loss  0.907212
# 2  top2_accuracy  0.855001
# 3  top3_accuracy  0.926928
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
#                    metric     value
# 0                accuracy  0.668954
# 4        accuracy_sklearn  0.668954
# 5       balanced_accuracy  0.668576
# 15            cohen_kappa  0.620346
# 8                f1_macro  0.662694
# 11            f1_weighted  0.671329
# 14               log_loss  0.907212
# 1                    loss  0.907212
# 16      matthews_corrcoef  0.621048
# 6         precision_macro  0.663264
# 9      precision_weighted  0.679178
# 7            recall_macro  0.668576
# 10        recall_weighted  0.668954
# 17      roc_auc_ovr_macro  0.939252
# 18   roc_auc_ovr_weighted  0.939758
# 2           top2_accuracy  0.855001
# 12  top2_accuracy_sklearn  0.855001
# 3           top3_accuracy  0.926928
# 13  top3_accuracy_sklearn  0.926928
#               precision    recall  f1-score      support
# anger          0.607029  0.616883  0.611916   924.000000
# contempt       0.600373  0.701200  0.646881   917.000000
# disgust        0.550562  0.600490  0.574443   816.000000
# fear           0.725301  0.615542  0.665929   978.000000
# happy          0.789229  0.763016  0.775901  1114.000000
# neutral        0.825215  0.727273  0.773154  1188.000000
# sad            0.670230  0.614630  0.641227  1326.000000
# surprise       0.538173  0.709571  0.612100   606.000000
# accuracy       0.668954  0.668954  0.668954     0.668954
# macro avg      0.663264  0.668576  0.662694  7869.000000
# weighted avg   0.679178  0.668954  0.671329  7869.000000
#               precision    recall  f1-score   support
#
#        anger       0.61      0.62      0.61       924
#     contempt       0.60      0.70      0.65       917
#      disgust       0.55      0.60      0.57       816
#         fear       0.73      0.62      0.67       978
#        happy       0.79      0.76      0.78      1114
#      neutral       0.83      0.73      0.77      1188
#          sad       0.67      0.61      0.64      1326
#     surprise       0.54      0.71      0.61       606
#
#     accuracy                           0.67      7869
#    macro avg       0.66      0.67      0.66      7869
# weighted avg       0.68      0.67      0.67      7869
#           anger  contempt  disgust  fear  happy  neutral  sad  surprise
# anger       570        83       71    38     23       12   80        47
# contempt     63       643       50    22     19       40   43        37
# disgust      52        73      490    26     17       18  114        26
# fear         82        36       46   602     12        2   56       142
# happy        62        46       14    32    850       69   32         9
# neutral      32        72       36     4    112      864   36        32
# sad          71        87      152    57     40       28  815        76
# surprise      7        31       31    49      4       14   40       430
#              anger  contempt   disgust      fear     happy   neutral  \
# anger     0.616883  0.089827  0.076840  0.041126  0.024892  0.012987
# contempt  0.068702  0.701200  0.054526  0.023991  0.020720  0.043621
# disgust   0.063725  0.089461  0.600490  0.031863  0.020833  0.022059
# fear      0.083845  0.036810  0.047035  0.615542  0.012270  0.002045
# happy     0.055655  0.041293  0.012567  0.028725  0.763016  0.061939
# neutral   0.026936  0.060606  0.030303  0.003367  0.094276  0.727273
# sad       0.053544  0.065611  0.114630  0.042986  0.030166  0.021116
# surprise  0.011551  0.051155  0.051155  0.080858  0.006601  0.023102
#
#                sad  surprise
# anger     0.086580  0.050866
# contempt  0.046892  0.040349
# disgust   0.139706  0.031863
# fear      0.057260  0.145194
# happy     0.028725  0.008079
# neutral   0.030303  0.026936
# sad       0.614630  0.057315
# surprise  0.066007  0.709571
#     accuracy      loss  top2_accuracy  top3_accuracy  val_accuracy  val_loss  \
# 30  0.595283  1.097186       0.795735       0.889915      0.631673  0.997659
# 31  0.605469  1.074471       0.803225       0.894490      0.640061  0.979721
# 32  0.614021  1.055170       0.806493       0.894409      0.626843  1.010268
# 33  0.612332  1.043736       0.813193       0.900455      0.634977  0.993918
# 34  0.624016  1.025121       0.814664       0.902960      0.650610  0.951433
#
#     val_top2_accuracy  val_top3_accuracy  learning_rate
# 30           0.828800           0.908998        0.00001
# 31           0.833630           0.912176        0.00001
# 32           0.823843           0.907219        0.00001
# 33           0.827529           0.909761        0.00001
# 34           0.839095           0.916497        0.00001
# Saved model: /artifacts/models/face_emotion_efficientnetb0_mediapipe.keras
# Saved metadata: /artifacts/models/metadata_efficientnetb0_mediapipe.json
# Saved reports: /artifacts/outputs/efficientnetb0_reports
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved to Drive: /content/drive/MyDrive/Emotion_Detect_Models/EfficientNetB0/face_emotion_efficientnetb0_mediapipe.keras
# Saved to Drive: /content/drive/MyDrive/Emotion_Detect_Models/EfficientNetB0/metadata_efficientnetb0_mediapipe.json
# Saved to Drive: /content/drive/MyDrive/Emotion_Detect_Models/EfficientNetB0/best_efficientnetb0_emotion_model.keras
